# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import time
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.layers.merge import *
from numpy.random import shuffle
from numpy.random import seed

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #Load dataset

# %%
y = np.load('y.npy')
x = np.load('x.npy')
yval = np.load('yval.npy')
xval = np.load('xval.npy')

# %% [markdown]
# #Scaling and shuffle

# %%
def rgb2labels(img):
    
    
    labels = np.zeros((img.shape[0], img.shape[1], 2))
    labels[:, :, 0] = img / 255.
    labels[:, :, 1] = 1.0 - img / 255.
    return labels


def labels2rgb(lbs):
    idx = np.zeros((lbs.shape[0], lbs.shape[1]), dtype=np.int32)
    np.argmax(lbs, axis=-1, out=idx)
    return label2rgb(idx) * 255

# %%
y = np.array(list(map(lambda img: rgb2labels(img), y)),dtype='float')
yval = np.array(list(map(lambda img: rgb2labels(img), yval)),dtype='float')

# %%
xg = []
for ii in range(496):
  pg = cv2.cvtColor(x[ii], cv2.COLOR_BGR2GRAY)
  xg.append(pg)
  
g = np.asarray(xg)
g = g.reshape(496,250,250,1)
g.shape
# Out:
# (496, 250, 250, 1)

# %%
xg = []
for ii in range(48):
  pg = cv2.cvtColor(xval[ii], cv2.COLOR_BGR2GRAY)
  xg.append(pg)
  
gt = np.asarray(xg)
gt = gt.reshape(48,250,250,1)
gt.shape
# Out:
# (48, 250, 250, 1)

# %%
X=x/255
Xt=xval/255

# %%
from skimage.transform import rescale, resize
Xt = resize(Xt, (48,200,200,3), anti_aliasing=False)
gt = resize(gt, (48,200,200,1), anti_aliasing=False)
ytest = resize(yval, (48,200,200,2), anti_aliasing=False)
X = resize(X, (496, 200, 200,3), anti_aliasing=False)
g = resize(g, (496, 200, 200,1), anti_aliasing=False)
y = resize(y,(496, 200, 200,2), anti_aliasing=False)

# %%
g.shape
# Out:
# (496, 200, 200, 1)

# %% [markdown]
# #Train-test

# %%
X_test1 = Xt
X_test2 = gt
Y_test = ytest
X_train1 = X
X_train2 = g
Y_train= y

# %% [markdown]
# #Model

# %%
def dice(y_true, y_pred, smoothness=20.):
    """
    Dice coefficient
    https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient
    DICE = 2|target and prediction| / |target| + |prediction|
    """
    intersection = K.sum(y_true * y_pred, axis=-1)
    union = K.sum(y_true, axis=-1) + K.sum(y_pred, axis=-1)
    return K.mean((2. * intersection + smoothness) / (union + smoothness))
  
def dice_loss(y_true, y_pred):
    return 1-dice(y_true, y_pred)

# %%
def conv_block(tensor, nfilters, size=3, padding='same'):
    x = Conv2D(filters=nfilters, kernel_size=(size, size), padding=padding)(tensor)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(filters=nfilters, kernel_size=(size, size), padding=padding)(x) #,
                       #depth_multiplier=2)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x


def deconv_block(tensor, residual, nfilters, size=3, padding='same', strides=(2, 2)):
    y = Conv2DTranspose(nfilters, kernel_size=(size, size), strides=strides, padding=padding)(tensor)
    y = concatenate([residual, y], axis=3)
    y = conv_block(y, nfilters, size=size)
    return y
  
def Unet(img_height, img_width, dim=3, filters=64):
    input_layer = Input(shape=(img_height, img_width, dim))
    
    # down
    
    conv1 = conv_block(input_layer, nfilters=filters)
    conv1_out = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = conv_block(conv1_out, nfilters=filters*2)
    conv2_out = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = conv_block(conv2_out, nfilters=filters*4)
    conv3_out = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = conv_block(conv3_out, nfilters=filters*8)
    conv4_out = MaxPooling2D(pool_size=(5, 5))(conv4)
    conv5 = conv_block(conv4_out,  nfilters=filters*16)
    
    # up
    deconv6 = deconv_block(conv5, residual=conv4,  nfilters=filters*8, strides=(5,5))
    deconv7 = deconv_block(deconv6, residual=conv3, nfilters=filters*4)
    deconv8 = deconv_block(deconv7, residual=conv2, nfilters=filters*2, size=3)
    deconv9 = deconv_block(deconv8, residual=conv1, nfilters=filters)
    
    # "U" shape
    
    # output
   
    output_layer = Conv2D(filters=2, kernel_size=(1, 1))(deconv9)
    output_layer = BatchNormalization()(output_layer)
    output_layer = Activation('softmax')(output_layer)
    
    # compile
    model = Model(inputs=input_layer, outputs=output_layer)
    
    return model
    
def New_model(img_height, img_width, dim1=4, filters=32):
    
    input1 = Input(shape=(img_height, img_width, 3))
    input2 = Input(shape=(img_height, img_width, 1))
    
    combinedInput = concatenate([input1, input2], axis=3)
    
    #output_layer = Conv2D(filters=2, kernel_size=(1, 1))(combinedInput)
    m = Unet(img_height, img_width, dim1, filters)(combinedInput)
    
    
    model = Model(inputs=[input1, input2], outputs=m)
    model.compile(optimizer = Adam(lr = 1e-4), loss = dice_loss, metrics = ['accuracy',dice])
    
    return model

# %%
m = New_model(200, 200)

m.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_16 (InputLayer)           (None, 200, 200, 3)  0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           (None, 200, 200, 1)  0
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 200, 200, 4)  0           input_16[0][0]
#                                                                  input_17[0][0]
# __________________________________________________________________________________________________
# model_11 (Model)                (None, 200, 200, 2)  8642602     concatenate_26[0][0]
# ==================================================================================================
# Total params: 8,642,602
# Trainable params: 8,636,710
# Non-trainable params: 5,892
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(m)

# %%
start=time.time()
history = m.fit([X_train1, X_train2], Y_train,epochs=50, batch_size=20, verbose=1, validation_data=([X_test1, X_test2], Y_test))
end=time.time()
print("Time:")
print(end-start)
# Out:
# Train on 496 samples, validate on 48 samples
# Epoch 1/50
# 496/496 [==============================] - 30s 61ms/step - loss: 0.0261 - acc: 0.8279 - dice: 0.9739 - val_loss: 0.0209 - val_acc: 0.8783 - val_dice: 0.9791
# Epoch 2/50
# 496/496 [==============================] - 19s 37ms/step - loss: 0.0203 - acc: 0.9067 - dice: 0.9797 - val_loss: 0.0186 - val_acc: 0.8889 - val_dice: 0.9814
# Epoch 3/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0184 - acc: 0.9298 - dice: 0.9816 - val_loss: 0.0208 - val_acc: 0.8718 - val_dice: 0.9792
# Epoch 4/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0178 - acc: 0.9387 - dice: 0.9822 - val_loss: 0.0161 - val_acc: 0.9105 - val_dice: 0.9839
# Epoch 5/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0171 - acc: 0.9497 - dice: 0.9829 - val_loss: 0.0173 - val_acc: 0.9233 - val_dice: 0.9827
# Epoch 6/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0171 - acc: 0.9477 - dice: 0.9829 - val_loss: 0.0217 - val_acc: 0.8959 - val_dice: 0.9783
# Epoch 7/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0169 - acc: 0.9491 - dice: 0.9831 - val_loss: 0.0214 - val_acc: 0.8867 - val_dice: 0.9786
# Epoch 8/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0164 - acc: 0.9553 - dice: 0.9836 - val_loss: 0.0229 - val_acc: 0.8910 - val_dice: 0.9771
# Epoch 9/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0160 - acc: 0.9601 - dice: 0.9840 - val_loss: 0.0224 - val_acc: 0.8858 - val_dice: 0.9776
# Epoch 10/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0158 - acc: 0.9636 - dice: 0.9842 - val_loss: 0.0203 - val_acc: 0.9132 - val_dice: 0.9797
# Epoch 11/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0165 - acc: 0.9543 - dice: 0.9835 - val_loss: 0.0215 - val_acc: 0.8947 - val_dice: 0.9785
# Epoch 12/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0155 - acc: 0.9697 - dice: 0.9845 - val_loss: 0.0209 - val_acc: 0.9037 - val_dice: 0.9791
# Epoch 13/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0152 - acc: 0.9721 - dice: 0.9848 - val_loss: 0.0195 - val_acc: 0.9158 - val_dice: 0.9805
# Epoch 14/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0153 - acc: 0.9673 - dice: 0.9847 - val_loss: 0.0182 - val_acc: 0.9300 - val_dice: 0.9818
# Epoch 15/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0155 - acc: 0.9639 - dice: 0.9845 - val_loss: 0.0191 - val_acc: 0.9216 - val_dice: 0.9809
# Epoch 16/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0152 - acc: 0.9658 - dice: 0.9848 - val_loss: 0.0199 - val_acc: 0.9080 - val_dice: 0.9801
# Epoch 17/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0152 - acc: 0.9683 - dice: 0.9848 - val_loss: 0.0186 - val_acc: 0.9169 - val_dice: 0.9814
# Epoch 18/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0151 - acc: 0.9701 - dice: 0.9849 - val_loss: 0.0199 - val_acc: 0.9060 - val_dice: 0.9801
# Epoch 19/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0158 - acc: 0.9591 - dice: 0.9842 - val_loss: 0.0163 - val_acc: 0.9195 - val_dice: 0.9837
# Epoch 20/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0150 - acc: 0.9673 - dice: 0.9850 - val_loss: 0.0182 - val_acc: 0.9189 - val_dice: 0.9818
# Epoch 21/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0146 - acc: 0.9738 - dice: 0.9854 - val_loss: 0.0191 - val_acc: 0.9148 - val_dice: 0.9809
# Epoch 22/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0142 - acc: 0.9764 - dice: 0.9858 - val_loss: 0.0185 - val_acc: 0.9313 - val_dice: 0.9815
# Epoch 23/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0141 - acc: 0.9756 - dice: 0.9859 - val_loss: 0.0178 - val_acc: 0.9328 - val_dice: 0.9822
# Epoch 24/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0143 - acc: 0.9767 - dice: 0.9857 - val_loss: 0.0180 - val_acc: 0.9323 - val_dice: 0.9820
# Epoch 25/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0140 - acc: 0.9781 - dice: 0.9860 - val_loss: 0.0181 - val_acc: 0.9267 - val_dice: 0.9819
# Epoch 26/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0138 - acc: 0.9774 - dice: 0.9862 - val_loss: 0.0179 - val_acc: 0.9303 - val_dice: 0.9821
# Epoch 27/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0140 - acc: 0.9780 - dice: 0.9860 - val_loss: 0.0184 - val_acc: 0.9235 - val_dice: 0.9816
# Epoch 28/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0141 - acc: 0.9753 - dice: 0.9859 - val_loss: 0.0212 - val_acc: 0.8855 - val_dice: 0.9788
# Epoch 29/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0138 - acc: 0.9767 - dice: 0.9862 - val_loss: 0.0189 - val_acc: 0.9164 - val_dice: 0.9811
# Epoch 30/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0138 - acc: 0.9786 - dice: 0.9862 - val_loss: 0.0172 - val_acc: 0.9391 - val_dice: 0.9828
# Epoch 31/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0135 - acc: 0.9795 - dice: 0.9865 - val_loss: 0.0174 - val_acc: 0.9296 - val_dice: 0.9826
# Epoch 32/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0131 - acc: 0.9809 - dice: 0.9869 - val_loss: 0.0190 - val_acc: 0.9031 - val_dice: 0.9810
# Epoch 33/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0134 - acc: 0.9802 - dice: 0.9866 - val_loss: 0.0180 - val_acc: 0.9215 - val_dice: 0.9820
# Epoch 34/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0133 - acc: 0.9827 - dice: 0.9867 - val_loss: 0.0183 - val_acc: 0.9128 - val_dice: 0.9817
# Epoch 35/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0129 - acc: 0.9840 - dice: 0.9871 - val_loss: 0.0179 - val_acc: 0.9254 - val_dice: 0.9821
# Epoch 36/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0130 - acc: 0.9834 - dice: 0.9870 - val_loss: 0.0174 - val_acc: 0.9287 - val_dice: 0.9826
# Epoch 37/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0128 - acc: 0.9844 - dice: 0.9872 - val_loss: 0.0185 - val_acc: 0.9127 - val_dice: 0.9815
# Epoch 38/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0128 - acc: 0.9832 - dice: 0.9872 - val_loss: 0.0197 - val_acc: 0.8952 - val_dice: 0.9803
# Epoch 39/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0130 - acc: 0.9828 - dice: 0.9870 - val_loss: 0.0174 - val_acc: 0.9258 - val_dice: 0.9826
# Epoch 40/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0129 - acc: 0.9805 - dice: 0.9871 - val_loss: 0.0169 - val_acc: 0.9319 - val_dice: 0.9831
# Epoch 41/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0130 - acc: 0.9835 - dice: 0.9870 - val_loss: 0.0178 - val_acc: 0.9182 - val_dice: 0.9822
# Epoch 42/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0129 - acc: 0.9838 - dice: 0.9871 - val_loss: 0.0170 - val_acc: 0.9290 - val_dice: 0.9830
# Epoch 43/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0125 - acc: 0.9850 - dice: 0.9875 - val_loss: 0.0178 - val_acc: 0.9201 - val_dice: 0.9822
# Epoch 44/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0126 - acc: 0.9837 - dice: 0.9874 - val_loss: 0.0172 - val_acc: 0.9260 - val_dice: 0.9828
# Epoch 45/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0126 - acc: 0.9843 - dice: 0.9874 - val_loss: 0.0164 - val_acc: 0.9318 - val_dice: 0.9836
# Epoch 46/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0126 - acc: 0.9829 - dice: 0.9874 - val_loss: 0.0174 - val_acc: 0.9206 - val_dice: 0.9826
# Epoch 47/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0124 - acc: 0.9817 - dice: 0.9876 - val_loss: 0.0187 - val_acc: 0.8944 - val_dice: 0.9813
# Epoch 48/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0123 - acc: 0.9846 - dice: 0.9877 - val_loss: 0.0164 - val_acc: 0.9273 - val_dice: 0.9836
# Epoch 49/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0131 - acc: 0.9818 - dice: 0.9869 - val_loss: 0.0169 - val_acc: 0.9237 - val_dice: 0.9831
# Epoch 50/50
# 496/496 [==============================] - 18s 37ms/step - loss: 0.0121 - acc: 0.9862 - dice: 0.9879 - val_loss: 0.0164 - val_acc: 0.9311 - val_dice: 0.9836
# Time:
# 936.183607339859

# %% [markdown]
# #Results

# %%
from skimage.color import label2rgb
p = m.predict([X_test1, X_test2],verbose=1)
#p  = np.reshape(p, (17,200,200))
#p = np.array(list(map(lambda img: labels2rgb(img), p)),dtype='float')
#Y_t = np.array(list(map(lambda img: labels2rgb(img), Y_test)),dtype='float')
# Out:
# 48/48 [==============================] - 4s 75ms/step

# %%
xval = resize(xval, (48, 250, 250,3))
Y_t = resize(Y_test, (48, 250, 250,2))
p = resize(p,(48, 250, 250,2))

# %%
def from_blocks2img(imgs, dim=1):
	nb = imgs.shape[0]
	ni = int(nb/16)
	X = imgs.reshape(ni, 16, imgs.shape[1], imgs.shape[2], dim)	
	output=[]
	for i in range(ni):
		R = X[i]
		a,b,c,d = np.split(R,4)
		B = np.concatenate((a,b,c,d), axis=1)
		a,b,c,d = np.split(B,4)
		R = np.concatenate((a,b,c,d), axis=2)
		R = R.reshape(1000, 1000, dim)
		output.append(R)
	return np.asarray(output)

# %%
original = from_blocks2img(xval,3)
b_truth = from_blocks2img(Y_t,2)
pred = from_blocks2img(p,2)

# %%
b_truth = np.array(list(map(lambda img: labels2rgb(img), b_truth)),dtype='float')
pred = np.array(list(map(lambda img: labels2rgb(img), pred)),dtype='float')

# %%
import matplotlib as mlp

default_figsize = mlp.rcParamsDefault['figure.figsize']
mlp.rcParams['figure.figsize'] = [v*2.2 for v in default_figsize]

for i in range(3):
  fig = plt.figure()
  a=fig.add_subplot(1,3,1)
  plt.imshow(original[i])
  a.set_title('Original')
  a=fig.add_subplot(1,3,2)
  plt.imshow(pred[i])
  a.set_title('Predicted')
  a=fig.add_subplot(1,3,3)
  plt.imshow(b_truth[i])
  a.set_title('Ground Truth')
  plt.show()
# Out:
# W0724 12:32:36.338759 140006971910016 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0724 12:32:36.384335 140006971910016 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0724 12:32:37.286748 140006971910016 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0724 12:32:37.332625 140006971910016 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0724 12:32:38.199045 140006971910016 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0724 12:32:38.244766 140006971910016 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
